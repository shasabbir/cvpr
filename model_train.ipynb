# %%
import os
import cv2
import random
import pickle
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %%
datapath = r"F:\face-mask-assignment\New Masks Dataset"
trainpath = os.path.join(datapath,'Train')
testpath = os.path.join(datapath,'Test')
validpath = os.path.join(datapath,'Validation')

# %%
IMG_SIZE = 227
CATEGORIES = []

for i in os.listdir(trainpath):
    CATEGORIES.append(i)
    
print(CATEGORIES)
# Out:
# ['Mask', 'Non Mask']

# %%
plt.figure(figsize=(15,4))
i=0
for c in CATEGORIES:  
    path = os.path.join(trainpath,c)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.subplot(2,10,i+1)
        plt.imshow(img_array)
        if i%10 == 0:
            plt.ylabel(c)
        plt.xticks([])
        plt.yticks([])
        i += 1
        if i%10 == 0:
            break

plt.tight_layout()        
plt.show()

# %%
training_data = []

for c in CATEGORIES:
    path = os.path.join(trainpath, c) 
    class_num = CATEGORIES.index(c) # 0
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))   # read the image
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize the image
            training_data.append([img_resized, class_num]) # [ [img, 0], [], [], [], ...., []]
        except WException as e:
            pass
        
print(len(training_data))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [00:09<00:00, 32.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 174.14it/s]
# 600

# %%
valid_data = []

for c in CATEGORIES:
    path = os.path.join(validpath, c) 
    class_num = CATEGORIES.index(c) 
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))   
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  
            valid_data.append([img_resized, class_num])
        except WException as e:
            pass
        
print(len(valid_data))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 153/153 [00:05<00:00, 26.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 153/153 [00:04<00:00, 33.14it/s]
# 306

# %%
test_data = []

for c in CATEGORIES:
    path = os.path.join(testpath, c) 
    class_num = CATEGORIES.index(c) 
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))   
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  
            test_data.append([img_resized, class_num])
        except WException as e:
            pass
        
print(len(test_data))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 24.90it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 40.78it/s]
# 100

# %%
random.shuffle(training_data)
random.shuffle(valid_data)
random.shuffle(test_data)

# %%
X_train = []
Y_train = []

for img, label in training_data:
    X_train.append(img)
    Y_train.append(label)
    
X_train = np.array(X_train).astype('float32').reshape(-1,227,227,3)
Y_train = np.array(Y_train)

print(f"X_train= {X_train.shape} Y_train= {Y_train.shape}")
# Out:
# X_train= (600, 227, 227, 3) Y_train= (600,)

# %%
X_valid = []
Y_valid = []

for img, label in valid_data:
    X_valid.append(img)
    Y_valid.append(label)
    
X_valid = np.array(X_valid).astype('float32').reshape(-1,227,227,3)
Y_valid = np.array(Y_valid)

print(f"X_valid= {X_valid.shape} Y_valid= {Y_valid.shape}")
# Out:
# X_valid= (306, 227, 227, 3) Y_valid= (306,)

# %%
X_test = []
Y_test = []

for features,label in test_data:
    X_test.append(features)
    Y_test.append(label)

X_test = np.array(X_test).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_test = np.array(Y_test)

print(f"X_test= {X_test.shape} Y_test= {Y_test.shape}")
# Out:
# X_test= (100, 227, 227, 3) Y_test= (100,)

# %%
import os
import cv2
import pickle
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
mean_img = np.mean(X_train, axis=0)
plt.imshow(mean_img.astype('uint8'))

# %%
X_train_norm, X_valid_norm, X_test_norm = X_train-mean_img, X_valid-mean_img, X_test-mean_img

# %%
c = 0
plt.figure(figsize=(5,10))
for i in range(5):
    plt.subplot(5,2,c+1)
    plt.imshow(X_train[i].astype('uint8'))
    plt.xticks([])
    plt.yticks([])
    
    plt.subplot(5,2,c+2)
    plt.imshow(X_train_norm[i].astype('uint8'))
    plt.xticks([])
    plt.yticks([])

    c += 2
    
plt.tight_layout()
plt.show()

# %%
model = keras.Sequential([
    ## input layer
    keras.Input(shape=X_train.shape[1:]),
    
    
    layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), padding='valid'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'),
    layers.BatchNormalization(),
    
    layers.Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding='valid'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'),
    layers.BatchNormalization(),
    
    layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'),
    layers.Activation('relu'),
    layers.BatchNormalization(),
    
    layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'),
    layers.Activation('relu'),
    layers.BatchNormalization(),
    
    layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'),
    layers.BatchNormalization(),
    
    layers.Flatten(),
    
    layers.Dense(units=4096),
    layers.Activation('relu'),
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    
    layers.Dense(units=4096),
    layers.Activation('relu'),
    layers.Dropout(0.5),
    layers.BatchNormalization(),

    layers.Dense(2),
    layers.Activation('softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# activation (Activation)      (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 17, 17, 256)       2973952
# _________________________________________________________________
# activation_1 (Activation)    (None, 17, 17, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 6, 384)         1536
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 4, 384)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 384)         1536
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 8194
# _________________________________________________________________
# activation_7 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 23,986,946
# Trainable params: 23,967,810
# Non-trainable params: 19,136
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h = model.fit(x=X_train_norm, y=Y_train, epochs=20, validation_data=(X_valid_norm, Y_valid), batch_size=32)
# Out:
# Epoch 1/20
# 19/19 [==============================] - 68s 3s/step - loss: 1.5212 - accuracy: 0.7125 - val_loss: 95.0545 - val_accuracy: 0.5000
# Epoch 2/20
# 19/19 [==============================] - 54s 3s/step - loss: 0.9225 - accuracy: 0.8351 - val_loss: 88.0233 - val_accuracy: 0.5065
# Epoch 3/20
# 19/19 [==============================] - 28565s 1587s/step - loss: 0.4541 - accuracy: 0.8490 - val_loss: 34.3549 - val_accuracy: 0.5163
# Epoch 4/20
# 19/19 [==============================] - 45s 2s/step - loss: 0.4840 - accuracy: 0.8449 - val_loss: 12.9729 - val_accuracy: 0.6667
# Epoch 5/20
# 19/19 [==============================] - 42s 2s/step - loss: 0.2047 - accuracy: 0.9243 - val_loss: 1.2692 - val_accuracy: 0.7516
# Epoch 6/20
# 19/19 [==============================] - 40s 2s/step - loss: 0.2495 - accuracy: 0.9043 - val_loss: 0.8647 - val_accuracy: 0.8203
# Epoch 7/20
# 19/19 [==============================] - 40s 2s/step - loss: 0.1902 - accuracy: 0.9272 - val_loss: 1.1808 - val_accuracy: 0.7222
# Epoch 8/20
# 19/19 [==============================] - 44s 2s/step - loss: 0.2333 - accuracy: 0.9195 - val_loss: 2.4077 - val_accuracy: 0.6993
# Epoch 9/20
# 19/19 [==============================] - 44s 2s/step - loss: 0.2021 - accuracy: 0.9252 - val_loss: 0.7689 - val_accuracy: 0.8170
# Epoch 10/20
# 19/19 [==============================] - 43s 2s/step - loss: 0.3171 - accuracy: 0.9141 - val_loss: 0.9201 - val_accuracy: 0.7810
# Epoch 11/20
# 19/19 [==============================] - 41s 2s/step - loss: 0.2001 - accuracy: 0.9053 - val_loss: 0.9608 - val_accuracy: 0.7810
# Epoch 12/20
# 19/19 [==============================] - 39s 2s/step - loss: 0.1643 - accuracy: 0.9494 - val_loss: 0.7106 - val_accuracy: 0.8137
# Epoch 13/20
# 19/19 [==============================] - 40s 2s/step - loss: 0.1564 - accuracy: 0.9514 - val_loss: 0.5630 - val_accuracy: 0.8497
# Epoch 14/20
# 19/19 [==============================] - 41s 2s/step - loss: 0.1664 - accuracy: 0.9380 - val_loss: 1.4258 - val_accuracy: 0.7157
# Epoch 15/20
# 19/19 [==============================] - 41s 2s/step - loss: 0.2333 - accuracy: 0.9155 - val_loss: 0.9487 - val_accuracy: 0.7582
# Epoch 16/20
# 19/19 [==============================] - 41s 2s/step - loss: 0.1345 - accuracy: 0.9464 - val_loss: 0.4571 - val_accuracy: 0.8791
# Epoch 17/20
# 19/19 [==============================] - 40s 2s/step - loss: 0.1221 - accuracy: 0.9477 - val_loss: 0.6344 - val_accuracy: 0.7549
# Epoch 18/20
# 19/19 [==============================] - 40s 2s/step - loss: 0.0562 - accuracy: 0.9788 - val_loss: 0.7158 - val_accuracy: 0.8431
# Epoch 19/20
# 19/19 [==============================] - 41s 2s/step - loss: 0.1152 - accuracy: 0.9658 - val_loss: 0.7152 - val_accuracy: 0.8301
# Epoch 20/20
# 19/19 [==============================] - 41s 2s/step - loss: 0.1305 - accuracy: 0.9488 - val_loss: 0.5550 - val_accuracy: 0.8072

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
if os.path.isfile('F:/face-mask-assignment/New Masks Dataset/model/face_mask_detection_model.h5') is False:
    model.save('F:/face-mask-assignment/New Masks Dataset/model/face_mask_detection_model.h5')

# %%
test_loss, test_acc = model.evaluate(X_test_norm, Y_test)
print('\nTest Accuracy:', test_acc)
print('\nTest Loss:', test_loss)
# Out:
# 4/4 [==============================] - 1s 334ms/step - loss: 0.9776 - accuracy: 0.8600
#
# Test Accuracy: 0.8600000143051147
#
# Test Loss: 0.9775940775871277
